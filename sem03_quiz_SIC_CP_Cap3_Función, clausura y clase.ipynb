# %% [markdown]
# # Coding and Programming
#
# ## Capítulo 3
#
# ### Función, clausura y clase
#
# - **Unidad 17.** Función
# - **Unidad 18.** Llamada a la función de recurrencia.
# - **Unidad 19.** Lambda
# - **Unidad 20.** Clausura
# - **Unidad 21.** Clase
#
# # Quiz 3

# %% [markdown]
# ___

# %% [markdown]
# ## Q 17-01
#
# Reciba las coordenadas `(x1, y1), (x2, y2)` de dos puntos del usuario e imprima la distancia entre los dos puntos de la siguiente manera. Para hacer esto, implemente la función `distancia(x1, y1, x2, y2)`.
#
#
# **Pauta de código:** consulte la fórmula para encontrar la distancia entre dos puntos.

# %% [markdown]
# *Respuesta:*
#
#
# ```
# import math
#
# def distancia(x1, y1, x2, y2):
#     distancia = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
#     return print('La distancia es: {}'.format(distancia))
#
# x1 = float(input("Ingrese la coordenada x1: "))
# y1 = float(input("Ingrese la coordenada y1: "))
# x2 = float(input("Ingrese la coordenada x2: "))
# y2 = float(input("Ingrese la coordenada y2: "))
#
# distancia(x1, y1, x2, y2)
# ```

# %% [markdown]
# ## Q 18-01
#
# Un palíndromo es una oración, palabra o cadena que es lo mismo que leer cualquier carácter de forma consecutiva.
#
# Por ejemplo, hay palabras como level, kayak, salas, somos, radar, reconocer.
#
# Usemos una llamada recursiva para determinar el palíndromo.
#
# Defina una función llamada `is_palindrome` y escriba un programa que reciba una cadena del usuario e imprima si el palindrome es correcto o no.
#
# **Pauta de código:** Llame a la función `is_palindrome` dentro de la función `is_palindrome`

# %% [markdown]
# *Respuesta:*
#
# ```
# def is_palindrome(s):
#   # Verificar si la cadena esta vacía o es de un solo carácter.
#   if len(s) <= 1:
#     return True
#   # Comparar el primer y último carácter.
#   if s[0] != s[-1]:
#     return False
#   # Llamada recursiva a la subcadena sin el primer y último carácter.
#   return is_palindrome(s[1:-1])
#
#
# cadena = input("Ingrese una cadena: ")
#
# if is_palindrome(cadena) == True:
#   print("La cadena es un palíndromo.")
# else:
#   print("La cadena no es un palíndromo.")
# ```

# %% [markdown]
# ## Q 19-01
#
#
# Después de poner una lista llamada `n_list` con valores de `[10, 20, 30]` en la función `map`.
#
# ```
# n_list = [10,20,30]
# twice  = list(map(lambda x: x*2, n_list))
# triple = list(map(lambda x: x*3, n_list))
# ```
#
# Indique el contenido de las variables `twice` y `triple`.

# %% [markdown]
# *Respuesta:*
#
# ```
# Al ejecutar twice, la funcion map va a evaluar cada elemento de "n_lista" en
# la funcion lambda, ademas al convertir map en una lista se ve que los elementos
# resultantes son el doble de los elementos evaluados:
#
# [20, 40, 60]
#
# Al ejecutar triple, la funcion map va a evaluar cada elemento de "n_lista" en
# la funcion lambda, ademas al convertir map en una lista se ve que los elementos
# resultantes son el triple de los elementos evaluados:
#
# [30, 60, 90]
# ```

# %% [markdown]
# ## Q 20-01
#
# En el siguiente código, espere qué valor se incluye finalmente en `num_list`. Calcule el resultado esperado a mano.
#
# **Pauta de codificación:** Escriba 5 veces la declaración `for`. Espere este resultado y envíe el resultado.
#
# ```
# def calc_digit(n):
#     def findal(digit):
#         return digit**n
#     return final
#
# num_list = []
# for num in range(1,6):
#     num_list.append( calc_digit(num) )
#     print( num_list[num-1](num) )
# ```

# %% [markdown]
# *Respuesta:*
#
#
# ```
# El codigo lo que hace es agarrar una lista de enteros y para cada elemento toma
# el valor de este y lo eleva al mismo valor(ejm: 2^2, 3^3, 4^4), y al final los
# almacena en una lista para imprimirlos
#
# 1- Primero se crea una lista vacia donde se van a almacenar los elemntos calculados.
#
# 2- Para un bucle que recorre una serie de elementos establecidos por range,
# toma el elemento ejecuta la funcion y lo agrega a la lista vacia.
#
# 3- La funcion a ejecutarse tiene como entrada el elemnto del bucle para hacer
# la operacion. La funcion es una funcion anidada, la primera establece el numero
# que va a ser la potencia, la segunda funcion toma este mismo numero para ser el
# numero el cual se va a elevar, y  devuelve el valor para almacenarse en la
# lista.
#
# 4- Finalmente se imprime cada elemento de la lista, sin embargo estos elementos
# son la funcion almacenada y por esto al final se llama la funcion con el
# elemnto del bucle para poder visualizar los datos.
#
# El codigo al ejecutarse imprime los resultados para 1,2,3,4 y 5, que serian los
# siguientes:
#
# 1
# 4
# 27
# 256
# 3125
#
# ```

# %% [markdown]
# ## Q 21-01
#
# Implemente las funciones de multiplicación (*) y división (/) de dos vectores usando los métodos `mul` y `truediv` aprendidos en la **unidad 21**. Suponiendo que `v1` es `(30, 40)` y `v2` es `(10, 20)`, codifique (escriba la declaración de salida) para devolver el siguiente resultado como resultado de la multiplicación y división de dos vectores.
#
#
# **Pauta de codificación:** escriba código que amplíe la funcionalidad de la clase `Vector2D` que aprendió en este capítulo.

# %% [markdown]
# *Respuesta:*
#
#
# ```
# class Vector2D:
#     def __init__(self, x, y):
#         self.x = x
#         self.y = y
#
#     def __mul__(self, otro):
#         """Multiplicación elemento a elemento"""
#         if isinstance(otro, Vector2D):
#             return Vector2D(self.x * otro.x, self.y * otro.y)
#         else:
#             return Vector2D(self.x * otro, self.y * otro)
#
#     def __truediv__(self, otro):
#         """División elemento a elemento"""
#         if isinstance(otro, Vector2D):
#             return Vector2D(self.x / otro.x, self.y / otro.y)
#         else:
#             return Vector2D(self.x / otro, self.y / otro)
#
#
# v1 = Vector2D(30, 40)
# v2 = Vector2D(10, 20)
#
# resultado_multiplicacion = v1 * v2
# print("Multiplicación. En x:", resultado_multiplicacion.x, "En y:", resultado_multiplicacion.y)
#
# resultado_division = v1 / v2
# print("División.       En y:", resultado_division.x, "En y:", resultado_division.y)
# ```

# %% [markdown]
# ___

# %% [markdown]
# # Fin
