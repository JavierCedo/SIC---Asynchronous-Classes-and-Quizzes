# %% [markdown]
# # Coding and Programming
#
# ## Capítulo 4
#
# ### Estructuras de Datos
#
# - **Unidad 17.** Pila
# - **Unidad 18.** Cola
# - **Unidad 19.** Búsqueda Binaria
# - **Unidad 20.** Tabla Hash
#
# # Quiz 4

# %% [markdown]
# ___

# %% [markdown]
# ## Q 22-01
#
# La siguiente es la implantación de una pila. ¿Cuál será el resultado del siguiente código?
#
# ```
# stack = Stack()
# stack.push("Banana")
# stack.push("Apple")
# stack.push("Tomato")
# stack.pop()
# stack.push("Strawberry")
# stack.push("Grapes")
# stack.pop()
# print(stack.stack)
# ```
#
# **Respuesta:**

# %% [markdown]
# El resultado final es el siguiente:
#
# ```
# ['Banana', 'Apple', 'Strawberry']
# ```
#
# Ya que se agrega: Banana, Apple, Tomato. Luego se elimina el ultimo ,y se agrega Strawberry y Grapes. Finalamente se elimina el ultimo agregado y se imprime.

# %% [markdown]
# ___

# %% [markdown]
# ## Q 22-02
#
# La siguiente es la implantación de una pila. ¿Cuál será el resultado del siguiente código?
#
# ```
# stack = Stack()
# items = [10 * i for i in range(1,10)]
# for item in items:
#     stack.push(item)
#     if (item // 10) % 2 == 0:
#         stack.pop()
# print(stack.stack)
# ```
#
# **Respuesta:**

# %% [markdown]
# El resultado final es el siguiente:
#
# ```
# [10, 30, 50, 70, 90]
# ```
# Primero se crea en Stack y una lista de 9 items. [10, 20, 30, 40, 50, 60, 70, 80, 90], luego se evalua cada item por un bucle for que comprueba que si el item dividido entre 10 y divido entre 2, su residuo resultante es igual a cero se elimina de la lista Stack el ultimo elemento agrega, que seria este item evaluado. Finalmente se improme dejando a items con valores impares en la lista Stack.

# %% [markdown]
# ___

# %% [markdown]
# ## Q 23-01
#
# La siguiente es la implantación de una cola. ¿Cuál será el resultado del siguiente código?
#
# ```
# queue = Queue()
# queue.enqueue("Banana")
# queue.enqueue("Apple")
# queue.enqueue("Tomato")
# queue.dequeue()
# queue.enqueue("Strawberry")
# queue.enqueue("Grapes")
# queue.dequeue()
# print(queue.queue)
# ```
#
# **Respuesta:**

# %% [markdown]
# El resultado final es el siguiente:
#
# ```
# ['Tomato', 'Strawberry', 'Grapes']
# ```
#
# Primero se genera una cola queue donde se almacenan los datos, se agregan: Banana, Apple y Tomato. Luego se elimina el primer elemento de la cola (Banana) y se agregan dos mas: Strawberry y Grapes. Finalmente se elimina el primer elemento (Apple) y se imprime la cola resultante.

# %% [markdown]
# ___

# %% [markdown]
# ## Q 23-02
#
# La siguiente es la implantación de una cola. ¿Cuál será el resultado del siguiente código?
#
# ```
# queue = Queue()
# items = [10 * i for i in range(1,10)]
# for item in items:
#     queue.enqueue(item)
#     if (item // 10) % 2 == 0:
#         queue.dequeue()
# print(queue.queue)
# ```
#
# **Respuesta:**

# %% [markdown]
# El resultado final es el siguiente:
#
# ```
# [50, 60, 70, 80, 90]
# ```
#
# Primero se genera una cola y se genera una lista de 9 items [10, 20, 30, 40, 50, 60, 70, 80, 90], luego se evalua cada item por un bucle for que comprueba que si el item dividido entre 10 y divido entre 2, el residuo resultante es igual a cero se elimina el primer elemento de la cola. Finalmente se imprime la cola elimando asi a [10, 20, 30, 40].

# %% [markdown]
# ___

# %% [markdown]
# ## Q 24-01
#
# ¿Cuál es el algoritmo de la siguiente función `find_two()`?
# ```
# def find_two():
#     x = y = 0
#     for i in range(1, len(nums)):
#         if nums[x] < nums[i]:
#             x = i
#         elif nums[y] > nums[i]:
#             y = i
#     return x,y
#
# nums = [11, 37, 45, 26, 59, 28, 17, 53]
# i,j = find_two(nums)
# print(nums[i], nums[j])
# ```
# Analice el código y escriba el resultado de la ejecución.

# %% [markdown]
# **Respuesta:**
#
# El resultado final es el siguiente:
#
# 59 11
#
# El programa lo que hace es imrpimir dos valores que se encuentran en una lista, el primer valor es el mayo y el segundo es el menor. Genera dos varialbes vacias "X" y "Y" para almacenar los valores que se van comparando.
# Se ejecuta un bucle for para hacer la comparacion de los numeros, tomando asi cada item y comparandolos con el valor almacenado en la varialbe, si el valor del item que se esta evaluando es mayor o menor al almacenado, este es sustituido por el almacendado, asi finalamente guardando el valor mas grande y el valor mas pequeño de la lista.
#
# En el llamado se hace "i, j = find_two(nums)" ya que la funcion devuelve "x" y "y".

# %% [markdown]
# ___

# %% [markdown]
# ## Q 24-02
#
# ¿Cuántas comparaciones debe realizar la función `find_two()` implementada en la pregunta anterior (24-01)?

# %% [markdown]
# **Respuesta:**
#
# Ocurren 11 comparaciones, donde la comparacion resulta o no resulta en algo, que serian las siguiente:
#
# 1 Surge un numero mayor (suma 1 en x)
# 2 Surge un numero mayor (suma 1 en x)
# 3 No ocurre nada
# 4 No ocurre nada
# 5 Surge un numero mayor (suma 1 en x)
# 6 No ocurre nada
# 7 No ocurre nada
# 8 No ocurre nada
# 9 No ocurre nada
# 10 No ocurre nada
# 11 No ocurre nada
#
# (y no cambia, y = 0)
#
# Finalmente se imprime los valores de los indices que corresponde al valor de "x" y "y", "x = 59" y "y = 11"

# %% [markdown]
# ___

# %% [markdown]
# ## Q 25-01
#
# El siguiente es el código para el juego de combinación de números.
#
# Si el máximo es 100 y el número es 51, ¿cuál es la salida de `count`?
# ```
# from random import randint
#
# maximo = int(input("Ingrese el número maximo: "))
# numero = int(input("Ingrese tu intento de adivinar el numero: "))
# low, high = 1, maximo
# count = 0
# while low < high:
#     count += 1
#     mid = (low + high) // 2
#     if mid == numero:
#         print(f"El número es {numero}")
#         break
#     elif mid > numero:
#         high = mid - 1
#     else:
#         low  = mid + 1
#
# print(f"Total {count} veces fue buscado.")
# ```

# %% [markdown]
# **Respuesta:**
#
# El resultado del conteo es "6", que sale de ejecutar el programa e introducir los valores 100 como maximo y 51 como numero a encontrar.

# %% [markdown]
# ___

# %% [markdown]
# ## Q 25-02
#
# En el código del juego de combinación de números, si el máximo es 100 y el número es 25, ¿cuál es el resultado del conteo?

# %% [markdown]
# **Respuesta:**
#
# El resultado del conteo es "2", que sale de ejecutar el programa e introducir los valores 100 como maximo y 25 como numero a encontrar.

# %% [markdown]
# ___

# %% [markdown]
# ## Q 26-01
#
# Usando la función hash de la clase HashTable, calcule la clave y la clave hash de "Alicia en el país de las maravillas" de la siguiente manera. (El valor clave es 1763.)
# ```
# table = HashTable(8)
# book  = "Alice in Wonderland"
# key = sum(map(ord, book))
# print(key, table.hash(key))
# ```

# %% [markdown]
# **Respuesta:**
#
# Para la clave 1763 que corresponde a "Alicia en el país de las maravillas", la clave hash es "3".

# %% [markdown]
# ___

# %% [markdown]
# ## Q 26-02
#
# Si la nueva estantería tiene 10 compartimentos, usa el siguiente código para averiguar qué libro hay en cada compartimento.
# ```
# table = HashTable(10)
# books = [
#     "The Little Prince",
#     "The Old Man and the Sea",
#     "The Little Memaid",
#     "Beauty and the Beast",
#     "The Last Leaf",
#     "Alice in Wonderland",
# ]
#
# for book in books:
#     key = sum(map(ord, book))
#     table.put(key, book)
#
# for key in table.table.keys():
#     print(key, table.table[key])
# ```

# %% [markdown]
# **Respuesta:**
#
# Al ejecutar el codigo, primero definiendo una plabla hash seguida del codigo proporcionado, el resultado generado es el siguiente:
#
# ```
# 0 []
# 1 []
# 2 []
# 3 ['The Last Leaf']
# 4 ['The Little Prince', 'The Little Memaid']
# 5 ['Alice in Wonderland']
# 6 []
# 7 ['Beauty and the Beast']
# 8 []
# 9 ['The Old Man and the Sea']
# ```

# %% [markdown]
# ___

# %% [markdown]
# # Fin
